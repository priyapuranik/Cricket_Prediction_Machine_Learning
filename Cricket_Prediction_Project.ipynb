# %%
#Importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the dataset 

match_data = pd.read_csv(r"C:\Users\Priya\Downloads\ODI_Match_Data.csv", low_memory=False)
match_info = pd.read_csv(r"C:\Users\Priya\Downloads\ODI_Match_info.csv")

# %% [markdown]
# ### Performing EDA (Exploratory Data Analysis)

# %%
#Checking the starting rows

match_data.head()
# Out:
#    match_id   season  start_date                           venue  innings  \
# 0   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 1   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 2   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 3   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 4   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
#
#    ball batting_team bowling_team     striker   non_striker  ... wides  \
# 0   0.1        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 1   0.2        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 2   0.3        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 3   0.4        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 4   0.5        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
#
#    noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# ...

# %%
#checking the starting rows of second dataset
match_info.head()
# Out:
#         id   season        city        date        team1       team2  \
# 0  1389389  2023/24      Indore  2023/09/24        India   Australia
# 1  1336129     2023  Nottingham  2023/09/23      England     Ireland
# 2  1395701     2023       Dhaka  2023/09/23  New Zealand  Bangladesh
# 3  1389388  2023/24  Chandigarh  2023/09/22    Australia       India
# 4  1395700     2023       Dhaka  2023/09/21  New Zealand  Bangladesh
#
#    toss_winner toss_decision  result  dl_applied       winner  win_by_runs  \
# 0    Australia         field     D/L           1        India           99
# 1      Ireland         field  normal           0      England           48
# 2  New Zealand           bat  normal           0  New Zealand           86
# 3        India         field  normal           0        India            0
# 4   Bangladesh         field  normal           0          NaN            0
#
#    win_by_wickets player_of_match  \
# 0               0         SS Iyer
# ...

# %%
print("rows and columns of match_data dataset= ",match_data.shape)
print("rows and columns of match_info dataset= ",match_info.shape)
# Out:
# rows and columns of match_data dataset=  (1265103, 23)
# rows and columns of match_info dataset=  (2379, 18)

# %%
# As we can see there are 1265103 rows and 23 columns in match_data dataset
# and 2379 rows and 18 columns in match_info dataset

# %%
match_data.tail()
# Out:
#          match_id   season  start_date                venue  innings  ball  \
# 1265098     64814  2002/03  2002-12-29  McLean Park, Napier        2  42.6
# 1265099     64814  2002/03  2002-12-29  McLean Park, Napier        2  43.1
# 1265100     64814  2002/03  2002-12-29  McLean Park, Napier        2  43.2
# 1265101     64814  2002/03  2002-12-29  McLean Park, Napier        2  43.3
# 1265102     64814  2002/03  2002-12-29  McLean Park, Napier        2  43.4
#
#         batting_team bowling_team    striker non_striker  ... wides  noballs  \
# 1265098        India  New Zealand  J Srinath      Z Khan  ...   NaN      NaN
# 1265099        India  New Zealand     Z Khan   J Srinath  ...   NaN      NaN
# 1265100        India  New Zealand  J Srinath      Z Khan  ...   NaN      NaN
# 1265101        India  New Zealand     Z Khan     A Nehra  ...   NaN      NaN
# 1265102        India  New Zealand     Z Khan     A Nehra  ...   NaN      NaN
#
# ...

# %%
match_data.tail()
# Out:
#          match_id   season  start_date                venue  innings  ball  \
# 1265098     64814  2002/03  2002-12-29  McLean Park, Napier        2  42.6
# 1265099     64814  2002/03  2002-12-29  McLean Park, Napier        2  43.1
# 1265100     64814  2002/03  2002-12-29  McLean Park, Napier        2  43.2
# 1265101     64814  2002/03  2002-12-29  McLean Park, Napier        2  43.3
# 1265102     64814  2002/03  2002-12-29  McLean Park, Napier        2  43.4
#
#         batting_team bowling_team    striker non_striker  ... wides  noballs  \
# 1265098        India  New Zealand  J Srinath      Z Khan  ...   NaN      NaN
# 1265099        India  New Zealand     Z Khan   J Srinath  ...   NaN      NaN
# 1265100        India  New Zealand  J Srinath      Z Khan  ...   NaN      NaN
# 1265101        India  New Zealand     Z Khan     A Nehra  ...   NaN      NaN
# 1265102        India  New Zealand     Z Khan     A Nehra  ...   NaN      NaN
#
# ...

# %%
#Descriptive Statistics
match_data.describe()
# Out:
#            match_id       innings          ball  runs_off_bat        extras  \
# count  1.265103e+06  1.265103e+06  1.265103e+06  1.265103e+06  1.265103e+06
# mean   7.121242e+05  1.456583e+00  2.265861e+01  7.895112e-01  4.896281e-02
# std    4.282254e+05  4.982083e-01  1.382100e+01  1.255689e+00  2.944322e-01
# min    6.481400e+04  1.000000e+00  1.000000e-01  0.000000e+00  0.000000e+00
# 25%    3.353520e+05  1.000000e+00  1.060000e+01  0.000000e+00  0.000000e+00
# 50%    6.490990e+05  1.000000e+00  2.210000e+01  0.000000e+00  0.000000e+00
# 75%    1.144494e+06  2.000000e+00  3.420000e+01  1.000000e+00  0.000000e+00
# max    1.395701e+06  4.000000e+00  4.990000e+01  7.000000e+00  6.000000e+00
#
#               wides      noballs         byes       legbyes  penalty  \
# count  28990.000000  5058.000000  1962.000000  12903.000000     18.0
# mean       1.204208     1.036576     2.056575      1.369061      5.0
# std        0.792682     0.320740     1.313392      0.884183      0.0
# ...

# %%
#Data types of each columns
match_data.dtypes
# Out:
# match_id                    int64
# season                     object
# start_date                 object
# venue                      object
# innings                     int64
# ball                      float64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                     float64
# noballs                   float64
# byes                      float64
# legbyes                   float64
# penalty                   float64
# wicket_type                object
# player_dismissed           object
# other_wicket_type         float64
# other_player_dismissed    float64
# cricsheet_id                int64
# dtype: object

# %%
match_info.describe()
# Out:
#                  id   dl_applied  win_by_runs  win_by_wickets
# count  2.379000e+03  2379.000000  2379.000000     2379.000000
# mean   7.114354e+05     0.084489    34.680538        2.750736
# std    4.287345e+05     0.278179    53.989592        3.238695
# min    6.481400e+04     0.000000     0.000000        0.000000
# 25%    3.353495e+05     0.000000     0.000000        0.000000
# 50%    6.490950e+05     0.000000     0.000000        0.000000
# 75%    1.144488e+06     0.000000    58.000000        6.000000
# max    1.395701e+06     1.000000   317.000000       10.000000

# %%
match_info.dtypes
# Out:
# id                  int64
# season             object
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
#To get all information of the data

match_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1265103 entries, 0 to 1265102
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   match_id                1265103 non-null  int64
#  1   season                  1265103 non-null  object
#  2   start_date              1265103 non-null  object
#  3   venue                   1265103 non-null  object
#  4   innings                 1265103 non-null  int64
#  5   ball                    1265103 non-null  float64
#  6   batting_team            1265103 non-null  object
#  7   bowling_team            1265103 non-null  object
#  8   striker                 1265103 non-null  object
#  9   non_striker             1265103 non-null  object
#  10  bowler                  1265103 non-null  object
#  11  runs_off_bat            1265103 non-null  int64
#  12  extras                  1265103 non-null  int64
# ...

# %%
match_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2379 entries, 0 to 2378
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2379 non-null   int64
#  1   season           2379 non-null   object
#  2   city             2069 non-null   object
#  3   date             2379 non-null   object
#  4   team1            2379 non-null   object
#  5   team2            2379 non-null   object
#  6   toss_winner      2379 non-null   object
#  7   toss_decision    2379 non-null   object
#  8   result           2379 non-null   object
#  9   dl_applied       2379 non-null   int64
#  10  winner           2259 non-null   object
#  11  win_by_runs      2379 non-null   int64
#  12  win_by_wickets   2379 non-null   int64
#  13  player_of_match  2228 non-null   object
#  14  venue            2379 non-null   object
#  15  umpire1          2379 non-null   object
#  16  umpire2          2379 non-null   object
# ...

# %%
#Random rows from data
match_data.sample(4)
# Out:
#          match_id   season  start_date                         venue  innings  \
# 646834     660825     2013  2013-08-27  Maple Leaf North-West Ground        1
# 580837     727923  2014/15  2014-10-12          Sheikh Zayed Stadium        1
# 1163613     66385  2004/05  2004-12-05             Docklands Stadium        2
# 1180613     65716     2004  2004-07-27           R.Premadasa Stadium        2
#
#          ball batting_team bowling_team        striker       non_striker  ...  \
# 646834   25.6  Netherlands       Canada      BN Cooper  T van der Gugten  ...
# 580837   14.5    Australia     Pakistan      SPD Smith         DA Warner  ...
# 1163613  21.6  New Zealand    Australia       NJ Astle       MS Sinclair  ...
# 1180613  41.6    Sri Lanka        India  ST Jayasuriya        TM Dilshan  ...
#
#         wides  noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# 646834    NaN      NaN   NaN      1.0      NaN          NaN               NaN
# ...

# %%
match_data.sample(4)
# Out:
#          match_id   season  start_date  \
# 1053449    249238  2006/07  2007-01-30
# 472467    1007653     2016  2016-06-15
# 687203     573015  2012/13  2013-01-13
# 851820     439141  2009/10  2010-03-06
#
#                                                 venue  innings  ball  \
# 1053449  Western Australia Cricket Association Ground        2   4.3
# 472467                             Harare Sports Club        1  31.4
# 687203                                  Adelaide Oval        2  27.2
# 851820                             Providence Stadium        1  44.6
#
#         batting_team bowling_team       striker      non_striker  ... wides  \
# 1053449      England  New Zealand       MB Loye         EC Joyce  ...   NaN
# 472467      Zimbabwe        India      T Maruma        MN Waller  ...   NaN
# 687203     Sri Lanka    Australia    TM Dilshan  HDRL Thirimanne  ...   NaN
# 851820      Zimbabwe  West Indies  E Chigumbura        AG Cremer  ...   NaN
#
# ...

# %%
#Checking the duplicates present in the data

match_info[match_info.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
match_data[match_data.duplicated(keep=False)]
# Out:
#          match_id   season  start_date  \
# 22333     1377770     2023  2023-07-02
# 22342     1377770     2023  2023-07-02
# 103976    1325549     2022  2022-08-18
# 103985    1325549     2022  2022-08-18
# 368977    1130737  2017/18  2018-01-15
# 368986    1130737  2017/18  2018-01-15
# 542492     656425  2014/15  2015-02-23
# 542501     656425  2014/15  2015-02-23
# 618837     636162  2013/14  2014-01-24
# 618846     636162  2013/14  2014-01-24
# 666740     566925     2013  2013-06-05
# 666749     566925     2013  2013-06-05
# 757076     516210     2011  2011-08-22
# 757085     516210     2011  2011-08-22
# 894617     350043     2009  2009-09-04
# 894626     350043     2009  2009-09-04
# 957646     345470     2008  2008-06-12
# 957655     345470     2008  2008-06-12
# 975729     325803  2007/08  2008-01-30
# 975738     325803  2007/08  2008-01-30
# 1035452    247468  2006/07  2007-03-19
# 1035461    247468  2006/07  2007-03-19
# 1203843     64852  2003/04  2003-11-30
# ...

# %%
#there are no duplicates in match_info dataset but present in match_data

# %%
match_data.shape
# Out:
# (1265103, 23)

# %%
#Checking the columns

match_data.columns
# Out:
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'penalty', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed', 'cricsheet_id'],
#       dtype='object')

# %%
match_info.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#Size of dataframe i.e no. of rows multiplied by number of columns
print(match_data.size)
print(match_info.size)
# Out:
# 29097369
# 42822

# %%
#number of unique entries over columns or rows
match_data.nunique()
# Out:
# match_id                  2379
# season                      43
# start_date                2012
# venue                      293
# innings                      4
# ball                       475
# batting_team                28
# bowling_team                28
# striker                   1741
# non_striker               1730
# bowler                    1342
# runs_off_bat                 8
# extras                       7
# wides                        5
# noballs                      5
# byes                         4
# legbyes                      5
# penalty                      1
# wicket_type                  9
# player_dismissed          1661
# other_wicket_type            0
# other_player_dismissed       0
# cricsheet_id              2379
# dtype: int64

# %%
match_info.nunique()
# Out:
# id                 2379
# season               43
# city                145
# date               2013
# team1                26
# team2                27
# toss_winner          27
# toss_decision         2
# result                2
# dl_applied            2
# winner               27
# win_by_runs         217
# win_by_wickets       11
# player_of_match     642
# venue               293
# umpire1             147
# umpire2             153
# umpire3             151
# dtype: int64

# %%
#correlation with other columns
match_data.corr()['wides']
# Out:
# C:\Users\Priya\AppData\Local\Temp\ipykernel_19636\2066434524.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   match_data.corr()['wides']
# match_id                 -0.012671
# innings                   0.014489
# ball                      0.020401
# runs_off_bat                   NaN
# extras                    0.999314
# wides                     1.000000
# noballs                        NaN
# byes                           NaN
# legbyes                        NaN
# penalty                        NaN
# other_wicket_type              NaN
# other_player_dismissed         NaN
# cricsheet_id             -0.012671
# Name: wides, dtype: float64

# %%
#Checking for the missing values
#we can use isna() also
match_data.isnull()
# Out:
#          match_id  season  start_date  venue  innings   ball  batting_team  \
# 0           False   False       False  False    False  False         False
# 1           False   False       False  False    False  False         False
# 2           False   False       False  False    False  False         False
# 3           False   False       False  False    False  False         False
# 4           False   False       False  False    False  False         False
# ...           ...     ...         ...    ...      ...    ...           ...
# 1265098     False   False       False  False    False  False         False
# 1265099     False   False       False  False    False  False         False
# 1265100     False   False       False  False    False  False         False
# 1265101     False   False       False  False    False  False         False
# 1265102     False   False       False  False    False  False         False
#
# ...

# %%
match_info.isnull()
# Out:
#          id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0     False   False  False  False  False  False        False          False
# 1     False   False  False  False  False  False        False          False
# 2     False   False  False  False  False  False        False          False
# 3     False   False  False  False  False  False        False          False
# 4     False   False  False  False  False  False        False          False
# ...     ...     ...    ...    ...    ...    ...          ...            ...
# 2374  False   False  False  False  False  False        False          False
# 2375  False   False  False  False  False  False        False          False
# 2376  False   False  False  False  False  False        False          False
# 2377  False   False  False  False  False  False        False          False
# 2378  False   False  False  False  False  False        False          False
#
# ...

# %%
#Total number of missing values

match_data.isnull().sum()
# Out:
# match_id                        0
# season                          0
# start_date                      0
# venue                           0
# innings                         0
# ball                            0
# batting_team                    0
# bowling_team                    0
# striker                         0
# non_striker                     0
# bowler                          0
# runs_off_bat                    0
# extras                          0
# wides                     1236113
# noballs                   1260045
# byes                      1263141
# legbyes                   1252200
# penalty                   1265085
# wicket_type               1230629
# player_dismissed          1230629
# other_wicket_type         1265103
# other_player_dismissed    1265103
# cricsheet_id                    0
# dtype: int64

# %%
match_info.isnull().sum()
# Out:
# id                   0
# season               0
# city               310
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner             120
# win_by_runs          0
# win_by_wickets       0
# player_of_match    151
# venue                0
# umpire1              0
# umpire2              0
# umpire3            282
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#Matches played in each seasons

plt.figure(figsize=(10,5))
sns.countplot(x='season',data=match_info)
plt.title('Number of Matches Per Season',fontsize=16, fontweight='bold')
plt.xlabel('Seasons',fontsize=12)
plt.ylabel('Number of Matches',fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
#calculations wins per team
team_wins = match_info['winner'].value_counts()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=team_wins.index, y=team_wins.values)
plt.title('Team-wise Wins',fontsize=16, fontweight='bold')
plt.xlabel('Team',fontsize=12,fontweight='bold')
plt.ylabel('Total Wins',fontsize=12,fontweight='bold')
plt.xticks(rotation=90, fontsize=10)
plt.show()

# %%
#Top player of match winner

top_player = match_info['player_of_match'].value_counts().head(10)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=top_player.values, y=top_player.index,)
plt.title('Top Player of the Match Winners',fontsize=16, fontweight='bold',
         bbox={'facecolor': 'yellow', 'alpha': 0.5, 'edgecolor': 'black', 'pad': 2})
plt.xlabel('Matches Won',fontsize=12,fontweight='bold')
plt.ylabel('Players',fontsize=12,fontweight='bold')
plt.show()

# %%
#match outcomes

plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = 'Comic Sans MS'
sns.histplot(match_info['win_by_runs'], bins=30,color='blue', edgecolor='black', kde=True)
plt.title('Distribution of Matches Won by Runs',fontsize=16, fontweight='bold')
plt.xlabel('Runs',fontsize=12, fontweight='bold')
plt.ylabel('Frequency',fontsize=12, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = 'Comic Sans MS'
sns.histplot(match_info['win_by_wickets'], bins=30, kde=True,color='blue')
plt.title('Distribution of Matches Won by Wickets',fontsize=16, fontweight='bold')
plt.xlabel('Wickets',fontsize=12, fontweight='bold')
plt.ylabel('Frequency',fontsize=12, fontweight='bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#toss decision
toss_decision = match_info['toss_decision'].value_counts()

# %%
plt.figure(figsize=(10,4))
plt.rcParams['font.family'] = 'Times New Roman'
colors = ['#ff9999','#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'] 

plt.pie(toss_decision.values, labels=toss_decision.index,autopct='%1.1f%%', shadow=True, startangle=140,
       colors=colors)
plt.axis('equal')
plt.title('Toss Decision Frequency',fontsize=16, fontweight='bold', 
          bbox={'facecolor': 'green', 'alpha': 0.5, 'edgecolor': 'black', 'pad': 3})
plt.show()

# %%
#correlation matrix
corr_matrix = match_info.corr(numeric_only=True)

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
#identifying top 10 run scorers
batsmen_total_runs = match_data.groupby(['striker'])['runs_off_bat'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12,6))

sns.barplot(x=batsmen_total_runs.values, y=batsmen_total_runs.index, orient='h')
plt.title('Top 10 Batsmens in ODIs', fontsize=16, fontdict={'family': 'Times New Roman'})
plt.xlabel('Scores',fontsize=12, fontdict={'family': 'Times New Roman'})
plt.ylabel('Batsman',fontsize=12, fontdict={'family': 'Times New Roman'})
plt.show()

# %%
#identifying top 10 wicket takers
top_bowlers_wickets = match_data[match_data['wicket_type'].notnull()].groupby('bowler')['wicket_type'].count().sort_values(ascending=False).head(10)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=top_bowlers_wickets.values, y=top_bowlers_wickets.index)

plt.title('Top 10 Wicket Takers in ODIs', fontsize=16, fontdict={'family': 'Times New Roman'}, fontweight='bold')
plt.xlabel('Wickets', fontsize=12, fontdict={'family': 'Times New Roman'}, fontweight='bold')
plt.ylabel('Bowler', fontsize=12, fontdict={'family': 'Times New Roman'}, fontweight='bold')
plt.show()

# %% [markdown]
# ## Data Cleaning

# %%
#Removing duplicates

match_data.drop_duplicates(inplace=True)

# %%
match_data.shape
# Out:
# (1265088, 23)

# %%
match_data[match_data.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [match_id, season, start_date, venue, innings, ball, batting_team, bowling_team, striker, non_striker, bowler, runs_off_bat, extras, wides, noballs, byes, legbyes, penalty, wicket_type, player_dismissed, other_wicket_type, other_player_dismissed, cricsheet_id]
# Index: []
#
# [0 rows x 23 columns]

# %%
#Converting date columns into datetime
match_info.dtypes
# Out:
# id                  int64
# season             object
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
match_info['date'] = pd.to_datetime(match_info['date'])

# %%
match_info.dtypes
# Out:
# id                          int64
# season                     object
# city                       object
# date               datetime64[ns]
# team1                      object
# team2                      object
# toss_winner                object
# toss_decision              object
# result                     object
# dl_applied                  int64
# winner                     object
# win_by_runs                 int64
# win_by_wickets              int64
# player_of_match            object
# venue                      object
# umpire1                    object
# umpire2                    object
# umpire3                    object
# dtype: object

# %%
match_data.dtypes
# Out:
# match_id                    int64
# season                     object
# start_date                 object
# venue                      object
# innings                     int64
# ball                      float64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                     float64
# noballs                   float64
# byes                      float64
# legbyes                   float64
# penalty                   float64
# wicket_type                object
# player_dismissed           object
# other_wicket_type         float64
# other_player_dismissed    float64
# cricsheet_id                int64
# dtype: object

# %%
match_data['start_date'] = pd.to_datetime(match_data['start_date'])

# %%
match_data.dtypes
# Out:
# match_id                           int64
# season                            object
# start_date                datetime64[ns]
# venue                             object
# innings                            int64
# ball                             float64
# batting_team                      object
# bowling_team                      object
# striker                           object
# non_striker                       object
# bowler                            object
# runs_off_bat                       int64
# extras                             int64
# wides                            float64
# noballs                          float64
# byes                             float64
# legbyes                          float64
# penalty                          float64
# wicket_type                       object
# player_dismissed                  object
# other_wicket_type                float64
# other_player_dismissed           float64
# cricsheet_id                       int64
# ...

# %%
# creating column total runs

match_data['total_runs'] = match_data['runs_off_bat'] + match_data['extras']

# %%
match_data.head(2)
# Out:
#    match_id   season start_date                           venue  innings  \
# 0   1389389  2023/24 2023-09-24  Holkar Cricket Stadium, Indore        1
# 1   1389389  2023/24 2023-09-24  Holkar Cricket Stadium, Indore        1
#
#    ball batting_team bowling_team     striker   non_striker  ... noballs  \
# 0   0.1        India    Australia  RD Gaikwad  Shubman Gill  ...     NaN
# 1   0.2        India    Australia  RD Gaikwad  Shubman Gill  ...     NaN
#
#    byes  legbyes  penalty  wicket_type  player_dismissed  other_wicket_type  \
# 0   NaN      NaN      NaN          NaN               NaN                NaN
# 1   NaN      NaN      NaN          NaN               NaN                NaN
#
#    other_player_dismissed cricsheet_id total_runs
# 0                     NaN      1389389          4
# 1                     NaN      1389389          0
#
# [2 rows x 24 columns]

# %%
score = match_data.groupby(['match_id', 'innings']).sum()['total_runs'].reset_index()
# Out:
# C:\Users\Priya\AppData\Local\Temp\ipykernel_19636\876885817.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   score = match_data.groupby(['match_id', 'innings']).sum()['total_runs'].reset_index()

# %%
score = score[score['innings']==1]
score
# Out:
#       match_id  innings  total_runs
# 0        64814        1         254
# 2        64815        1         108
# 4        64816        1         122
# 6        64817        1         168
# 8        64819        1         122
# ...        ...      ...         ...
# 4692   1390344        1         201
# 4694   1390345        1         300
# 4696   1390346        1         268
# 4698   1395700        1         136
# 4699   1395701        1         254
#
# [2379 rows x 3 columns]

# %%
# another dataset

matchdf = match_info.merge(score[['match_id', 'total_runs']], left_on='id', right_on='match_id')

# %%
teams = [ 'India',
    'England', 
    'New Zealand', 
    'Australia', 
    'Sri Lanka',
    'South Africa', 
    'Bangladesh', 
    'Pakistan', 
    'Nepal', 
    'Afghanistan',
    'West Indies', 
    'Scotland', 
    'United Arab Emirates', 
    'Oman',
    'Netherlands', 
    'Zimbabwe', 
    'United States of America', 
    'Ireland',
    'Canada', 
    'Namibia',
    'Papua New Guinea', 
    'Hong Kong',
    'Kenya',]

# %%
matchdf = matchdf[matchdf['team1'].isin(teams)]
matchdf = matchdf[matchdf['team2'].isin(teams)]

# %%
matchdf = matchdf[matchdf['dl_applied']==0]

# %%
matchdf = matchdf[['match_id','city', 'winner','total_runs']]

# %%
odi_df = matchdf.merge(match_data, on='match_id')

# %%
odi_df = odi_df[odi_df['innings'] ==2]

# %%
odi_df = odi_df.dropna(subset=['city','winner'])

# %%
print(odi_df['total_runs_y'].dtype)
# Out:
# int64

# %%
odi_df['currentscore'] = odi_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
odi_df['runs_left'] = odi_df['total_runs_x'] - odi_df['currentscore'] + 1

# %%
# Calculate balls bowled so far (cumulative count within each innings)
odi_df['balls_bowled'] = odi_df.groupby(['match_id', 'innings']).cumcount() + 1

# %%
odi_df['balls_left'] = 300 - odi_df['balls_bowled']

# %%
odi_df['balls_left'] = odi_df['balls_left'].apply(lambda x: max(x, 0))

# %%
odi_df.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'season', 'start_date',
#        'venue', 'innings', 'ball', 'batting_team', 'bowling_team', 'striker',
#        'non_striker', 'bowler', 'runs_off_bat', 'extras', 'wides', 'noballs',
#        'byes', 'legbyes', 'penalty', 'wicket_type', 'player_dismissed',
#        'other_wicket_type', 'other_player_dismissed', 'cricsheet_id',
#        'total_runs_y', 'currentscore', 'runs_left', 'balls_bowled',
#        'balls_left'],
#       dtype='object')

# %%
odi_df.head(4)
# Out:
#      match_id        city   winner  total_runs_x season start_date  \
# 310   1336129  Nottingham  England           334   2023 2023-09-23
# 311   1336129  Nottingham  England           334   2023 2023-09-23
# 312   1336129  Nottingham  England           334   2023 2023-09-23
# 313   1336129  Nottingham  England           334   2023 2023-09-23
#
#                         venue  innings  ball batting_team  ... wicket_type  \
# 310  Trent Bridge, Nottingham        2   0.1      Ireland  ...         NaN
# 311  Trent Bridge, Nottingham        2   0.2      Ireland  ...         NaN
# 312  Trent Bridge, Nottingham        2   0.3      Ireland  ...         NaN
# 313  Trent Bridge, Nottingham        2   0.4      Ireland  ...         NaN
#
#     player_dismissed other_wicket_type other_player_dismissed  cricsheet_id  \
# 310              NaN               NaN                    NaN       1336129
# 311              NaN               NaN                    NaN       1336129
# ...

# %%
odi_df['player_dismissed'] = odi_df['player_dismissed'].fillna('0')

# %%
odi_df['player_dismissed'] = odi_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")

# %%
#changing the datatye of the column player_dismissed

odi_df['player_dismissed'] = odi_df['player_dismissed'].astype('int')
odi_df
# Out:
#          match_id        city       winner  total_runs_x   season start_date  \
# 310       1336129  Nottingham      England           334     2023 2023-09-23
# 311       1336129  Nottingham      England           334     2023 2023-09-23
# 312       1336129  Nottingham      England           334     2023 2023-09-23
# 313       1336129  Nottingham      England           334     2023 2023-09-23
# 314       1336129  Nottingham      England           334     2023 2023-09-23
# ...           ...         ...          ...           ...      ...        ...
# 1158895     64814      Napier  New Zealand           254  2002/03 2002-12-29
# 1158896     64814      Napier  New Zealand           254  2002/03 2002-12-29
# 1158897     64814      Napier  New Zealand           254  2002/03 2002-12-29
# 1158898     64814      Napier  New Zealand           254  2002/03 2002-12-29
# 1158899     64814      Napier  New Zealand           254  2002/03 2002-12-29
#
# ...

# %%
wickets = odi_df.groupby('match_id')['player_dismissed'].cumsum()
odi_df['wickets_left'] = 10 - wickets
odi_df.tail(6)
# Out:
#          match_id    city       winner  total_runs_x   season start_date  \
# 1158894     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158895     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158896     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158897     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158898     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158899     64814  Napier  New Zealand           254  2002/03 2002-12-29
#
#                        venue  innings  ball batting_team  ...  \
# 1158894  McLean Park, Napier        2  42.5        India  ...
# 1158895  McLean Park, Napier        2  42.6        India  ...
# 1158896  McLean Park, Napier        2  43.1        India  ...
# 1158897  McLean Park, Napier        2  43.2        India  ...
# 1158898  McLean Park, Napier        2  43.3        India  ...
# 1158899  McLean Park, Napier        2  43.4        India  ...
#
# ...

# %%
#Current run rate

odi_df['crr'] = (odi_df['currentscore']*6)/(300 - odi_df['balls_left'])

# %%
# required run rate

odi_df['rrr'] = (odi_df['runs_left']*6)/odi_df['balls_left']

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0
odi_df['result'] = odi_df.apply(result, axis=1)

# %%
odi_df.result.value_counts()
# Out:
# 0    232324
# 1    223492
# Name: result, dtype: int64

# %%
odi_df.tail(8)
# Out:
#          match_id    city       winner  total_runs_x   season start_date  \
# 1158892     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158893     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158894     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158895     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158896     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158897     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158898     64814  Napier  New Zealand           254  2002/03 2002-12-29
# 1158899     64814  Napier  New Zealand           254  2002/03 2002-12-29
#
#                        venue  innings  ball batting_team  ... cricsheet_id  \
# 1158892  McLean Park, Napier        2  42.3        India  ...        64814
# 1158893  McLean Park, Napier        2  42.4        India  ...        64814
# 1158894  McLean Park, Napier        2  42.5        India  ...        64814
# ...

# %%
# Feature Selection

final = odi_df[['batting_team','bowling_team','city','runs_left','balls_left',
               'wickets_left','total_runs_x','crr','rrr','result']]

# %%
final = final.sample(final.shape[0])
final
# Out:
#              batting_team          bowling_team           city  runs_left  \
# 1106629       New Zealand                 India        Cuttack         91
# 805709         Bangladesh              Zimbabwe     Chittagong         98
# 420690        Afghanistan            Bangladesh         Mirpur        142
# 627438            England                 India     Dharamsala        171
# 922547       South Africa              Zimbabwe       Bulawayo         52
# ...                   ...                   ...            ...        ...
# 387188            Ireland           Afghanistan  Greater Noida        162
# 396317          Sri Lanka          South Africa         Durban        257
# 67058             England          South Africa   Bloemfontein        271
# 58459    Papua New Guinea  United Arab Emirates          Dubai         74
# 895015       South Africa           West Indies         Durban        239
#
#          balls_left  wickets_left  total_runs_x       crr       rrr  result
# ...

# %%
final.dropna(inplace=True)
final = final[(final['runs_left'] >= 0) & (final['balls_left'] >= 0)]
final.sample()
# Out:
#        batting_team bowling_team        city  runs_left  balls_left  \
# 919460      England        India  Manchester         92         141
#
#         wickets_left  total_runs_x       crr       rrr  result
# 919460             3           212  4.566038  3.914894       1

# %%
final.balls_left.value_counts()
# Out:
# 0      2774
# 290    1773
# 295    1773
# 287    1773
# 272    1773
#        ...
# 5       554
# 4       525
# 3       497
# 2       471
# 1       427
# Name: balls_left, Length: 300, dtype: int64

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 455239 entries, 1106629 to 895015
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   batting_team  455239 non-null  object
#  1   bowling_team  455239 non-null  object
#  2   city          455239 non-null  object
#  3   runs_left     455239 non-null  int64
#  4   balls_left    455239 non-null  int64
#  5   wickets_left  455239 non-null  int32
#  6   total_runs_x  455239 non-null  int64
#  7   crr           455239 non-null  float64
#  8   rrr           455239 non-null  float64
#  9   result        455239 non-null  int64
# dtypes: float64(2), int32(1), int64(4), object(3)
# memory usage: 36.5+ MB

# %% [markdown]
# ## One Hot Encoding

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
categorical_columns = ['batting_team', 'bowling_team', 'city']
ohe = OneHotEncoder(sparse_output=False, drop='first')

# %%
ohe_data= ohe.fit_transform(final[categorical_columns])

# %%
ohe_df = pd.DataFrame(ohe_data, columns=ohe.get_feature_names_out(categorical_columns))

# %%
final = pd.concat([final.drop(categorical_columns, axis=1), ohe_df], axis=1)

# %%
final.head()
# Out:
#          runs_left  balls_left  wickets_left  total_runs_x       crr  \
# 1106629       91.0       100.0           6.0         246.0  4.680000
# 805709        98.0       117.0           5.0         221.0  4.065574
# 420690       142.0       204.0           6.0         208.0  4.187500
# 627438       171.0       218.0           9.0         226.0  4.097561
# 922547        52.0        68.0           6.0         206.0  4.008621
#
#               rrr  result  batting_team_Australia  batting_team_Bangladesh  \
# 1106629  5.460000     1.0                     NaN                      NaN
# 805709   5.025641     1.0                     NaN                      NaN
# 420690   4.176471     1.0                     0.0                      0.0
# 627438   4.706422     1.0                     NaN                      NaN
# 922547   4.588235     1.0                     NaN                      NaN
#
#          batting_team_Canada  ...  city_Thiruvananthapuram  city_Toronto  \
# ...

# %%
final.columns
# Out:
# Index(['runs_left', 'balls_left', 'wickets_left', 'total_runs_x', 'crr', 'rrr',
#        'result', 'batting_team_Australia', 'batting_team_Bangladesh',
#        'batting_team_Canada',
#        ...
#        'city_Thiruvananthapuram', 'city_Toronto', 'city_Townsville',
#        'city_Trinidad', 'city_Utrecht', 'city_Vadodara', 'city_Visakhapatnam',
#        'city_Wellington', 'city_Whangarei', 'city_Windhoek'],
#       dtype='object', length=194)

# %%
final.isnull().sum()[final.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
final.dropna(inplace=True)

# %%
import numpy as np
import pandas as pd

# Assuming your DataFrame is named 'final'

# Check and handle infinity values
final.replace([np.inf, -np.inf], np.nan, inplace=True)

# Define a threshold for very large values based on float32 maximum value
very_large_threshold = np.finfo(np.float32).max

# Replace very large values with NaN
final[final > very_large_threshold] = np.nan

# Drop rows with NaN values
final.dropna(inplace=True)

print("Data cleaned from infinity and very large values.")
# Out:
# Data cleaned from infinity and very large values.

# %%
final.head(8)
# Out:
#         runs_left  balls_left  wickets_left  total_runs_x       crr  \
# 420690      142.0       204.0           6.0         208.0  4.187500
# 64935        16.0       177.0          10.0         153.0  6.731707
# 47130       189.0       188.0           9.0         279.0  4.875000
# 260821       89.0       178.0           6.0         164.0  3.737705
# 103468      312.0       294.0          10.0         311.0  0.000000
# 416849       56.0        56.0           6.0         309.0  6.245902
# 264137       70.0        67.0           9.0         284.0  5.536481
# 577          79.0        32.0           1.0         334.0  5.731343
#
#               rrr  result  batting_team_Australia  batting_team_Bangladesh  \
# 420690   4.176471     1.0                     0.0                      0.0
# 64935    0.542373     1.0                     0.0                      0.0
# 47130    6.031915     1.0                     0.0                      0.0
# ...

# %% [markdown]
# ## Model Building

# %%
X = final.drop('result', axis=1)
y = final['result']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = RandomForestClassifier(class_weight='balanced')
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9091470453996295
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.93      0.91     19079
#          1.0       0.93      0.89      0.90     18168
#
#     accuracy                           0.91     37247
#    macro avg       0.91      0.91      0.91     37247
# weighted avg       0.91      0.91      0.91     37247

# %%
final.balls_left.value_counts()
# Out:
# 286.0    731
# 284.0    731
# 288.0    731
# 268.0    731
# 276.0    731
#         ...
# 5.0      222
# 4.0      211
# 3.0      193
# 2.0      184
# 1.0      166
# Name: balls_left, Length: 299, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=15, criterion='gini',min_samples_split=6, class_weight='balanced')
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=15,
#                        min_samples_split=6)

# %%
pred_dt = dt.predict(X_test)

# %%
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93     19131
#          1.0       0.92      0.93      0.92     18116
#
#     accuracy                           0.93     37247
#    macro avg       0.93      0.93      0.93     37247
# weighted avg       0.93      0.93      0.93     37247

# %%
t_pred = dt.predict(X_train)

# %%
print(classification_report(y_train, t_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     76381
#          1.0       0.95      0.94      0.95     72606
#
#     accuracy                           0.95    148987
#    macro avg       0.95      0.95      0.95    148987
# weighted avg       0.95      0.95      0.95    148987

# %%
dt.feature_importances_
# Out:
# array([8.98393903e-02, 2.23758148e-02, 1.00698911e-01, 2.62250592e-01,
#        9.18653898e-02, 4.18281753e-01, 1.50076668e-04, 1.69214302e-04,
#        7.49083009e-05, 1.59909823e-04, 5.85926169e-05, 2.65074807e-04,
#        1.74506716e-04, 2.86482000e-05, 5.78504457e-05, 1.67715878e-04,
#        1.21002790e-04, 1.71884322e-04, 8.41066337e-05, 1.02490576e-04,
#        6.42922177e-05, 5.54503513e-05, 1.16230558e-04, 2.25702306e-04,
#        1.83469674e-04, 2.71242842e-05, 1.40885198e-04, 1.48627114e-04,
#        5.14767010e-05, 2.66816154e-04, 1.99311326e-04, 1.55636063e-04,
#        2.61709610e-05, 1.62814301e-04, 6.96783778e-05, 1.12556247e-04,
#        1.72831504e-04, 2.99167902e-05, 4.07850713e-05, 1.06857556e-04,
#        9.86647553e-05, 1.79976762e-04, 1.81343779e-04, 7.00079723e-06,
#        1.53038636e-04, 2.56038158e-04, 1.70658469e-04, 8.87858693e-05,
#        2.53519470e-04, 1.28667841e-04, 1.05482807e-04, 6.91087601e-05,
# ...

# %%
feat_imp = pd.DataFrame()
feat_imp['Features'] = X_train.columns
feat_imp['Importance'] = dt.feature_importances_
feat_imp = feat_imp.sort_values('Importance', ascending = False)
feat_imp.head(10)
# Out:
#                    Features  Importance
# 5                       rrr    0.418282
# 3              total_runs_x    0.262251
# 2              wickets_left    0.100699
# 4                       crr    0.091865
# 0                 runs_left    0.089839
# 1                balls_left    0.022376
# 84             city_Colombo    0.000281
# 29  bowling_team_Bangladesh    0.000267
# 11       batting_team_India    0.000265
# 45   bowling_team_Sri Lanka    0.000256

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred_log = logreg.predict(X_test)

# %%
print(classification_report(y_test,pred_log))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.81      0.81     19079
#          1.0       0.80      0.79      0.80     18168
#
#     accuracy                           0.80     37247
#    macro avg       0.80      0.80      0.80     37247
# weighted avg       0.80      0.80      0.80     37247

# %% [markdown]
# ## Exporting the model

# %%
import pickle
pickle.dump(dt, open('final_model2.pkl','wb'))

# %%
import pickle
from sklearn.preprocessing import OneHotEncoder

# Assuming ohe is your fitted OneHotEncoder
with open('encoder.pkl', 'wb') as f:
    pickle.dump(ohe, f)

# %%
# Save the feature names used during model training
import pickle

feature_names = ohe.get_feature_names_out()

# Save feature names
with open('feature_names.pkl', 'wb') as f:
    pickle.dump(feature_names, f)

# %%
# List of features used during model training
print(dt.feature_names_in_)
# print(ohe.get_feature_names_out())
# Out:
# ['runs_left' 'balls_left' 'wickets_left' 'total_runs_x' 'crr' 'rrr'
#  'batting_team_Australia' 'batting_team_Bangladesh' 'batting_team_Canada'
#  'batting_team_England' 'batting_team_Hong Kong' 'batting_team_India'
#  'batting_team_Ireland' 'batting_team_Kenya' 'batting_team_Namibia'
#  'batting_team_Nepal' 'batting_team_Netherlands'
#  'batting_team_New Zealand' 'batting_team_Oman' 'batting_team_Pakistan'
#  'batting_team_Papua New Guinea' 'batting_team_Scotland'
#  'batting_team_South Africa' 'batting_team_Sri Lanka'
#  'batting_team_United Arab Emirates'
#  'batting_team_United States of America' 'batting_team_West Indies'
#  'batting_team_Zimbabwe' 'bowling_team_Australia'
#  'bowling_team_Bangladesh' 'bowling_team_Canada' 'bowling_team_England'
#  'bowling_team_Hong Kong' 'bowling_team_India' 'bowling_team_Ireland'
#  'bowling_team_Kenya' 'bowling_team_Namibia' 'bowling_team_Nepal'
#  'bowling_team_Netherlands' 'bowling_team_New Zealand' 'bowling_team_Oman'
# ...

# %%
 print(ohe.get_feature_names_out())
# Out:
# ['batting_team_Australia' 'batting_team_Bangladesh' 'batting_team_Canada'
#  'batting_team_England' 'batting_team_Hong Kong' 'batting_team_India'
#  'batting_team_Ireland' 'batting_team_Kenya' 'batting_team_Namibia'
#  'batting_team_Nepal' 'batting_team_Netherlands'
#  'batting_team_New Zealand' 'batting_team_Oman' 'batting_team_Pakistan'
#  'batting_team_Papua New Guinea' 'batting_team_Scotland'
#  'batting_team_South Africa' 'batting_team_Sri Lanka'
#  'batting_team_United Arab Emirates'
#  'batting_team_United States of America' 'batting_team_West Indies'
#  'batting_team_Zimbabwe' 'bowling_team_Australia'
#  'bowling_team_Bangladesh' 'bowling_team_Canada' 'bowling_team_England'
#  'bowling_team_Hong Kong' 'bowling_team_India' 'bowling_team_Ireland'
#  'bowling_team_Kenya' 'bowling_team_Namibia' 'bowling_team_Nepal'
#  'bowling_team_Netherlands' 'bowling_team_New Zealand' 'bowling_team_Oman'
#  'bowling_team_Pakistan' 'bowling_team_Papua New Guinea'
# ...
